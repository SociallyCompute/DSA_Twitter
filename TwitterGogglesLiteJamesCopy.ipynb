# %% [markdown]
# # Twitter Goggles Lite
#
# Query the the Twitter Search API and return a structured table of results.

# %%
import numpy as np 
import pandas as pd

import argparse, collections, configparser, io, json, math, mysql.connector as sql, os, requests, sys, time
from datetime import datetime
from mysql.connector import errorcode
from requests import HTTPError
from requests import ConnectionError
from requests_oauthlib import OAuth1

# %% [markdown]
# The following script queries Twitter for tweets containing the name of 50 US cities in the body of the text as well as tweets withing a 40 km radius of that city. The 50 cities are listed within the `description` column of the `jobs.csv` file below and the query request are in the `query` column.

# %%
job = pd.read_csv('data/job.csv')
job.head()
# Out:
#    job_id  state  zombie_head  since_id_str              query  \
# 0     204     23            1  8.541130e+17           q=Warren
# 1     205     24            2  8.541160e+17           q=Fresno
# 2     206     25            3  8.541140e+17       q=Cincinnati
# 3     207     26            4  8.541170e+17  q=Oklahoma%20City
# 4     208     27            5  8.541150e+17        q=Allentown
#
#                description  last_count       last_run  analysis_state  \
# 0         Warren, Michigan         511  4/17/17 18:23               0
# 1       Fresno, California          87  4/17/17 18:37               0
# 2         Cincinnati, Ohio         113  4/17/17 18:25               0
# 3  Oklahoma City, Oklahoma          50  4/17/17 18:38               0
# 4  Allentown, Pennsylvania          23  4/17/17 18:33               0
#
#    oauth_id
# 0         4
# 1         5
# 2         6
# 3         7
# 4         8

# %% [markdown]
# In order to use the Search API, Twitter requires you to have authetication. Be sure to fill in the variables below with your Twitter creds, then run the cell.

# %%
consumer_key = 'H0pa8ePaLE9ZjRJp0BfFi5JVt'
consumer_secret = 'u2w1U1JccIrd5Zhy8O9ALPgdt1Z3xPyD3kJP8E8Q2AGde0jXpv'
access_token = '2882452026-qkvdVWqbNwJYktehDXlcensgRK6lZJG6cyWMPXm'
access_token_secret = '2V8jupOOtRYoNIkRLNewxc06vAuStj2ZcWAKa3fsZZUBw'


oauth = OAuth1(client_key=consumer_key,
    client_secret=consumer_secret,
    resource_owner_key=access_token,
    resource_owner_secret=access_token_secret)

# %% [markdown]
# To make a request to Twitter, we define a function that queries Twitter and returns a json object that we will then parse into dictionaries for the attributes that we are interested in.

# %%
def search(query, oauth) :
    print("Query: " + query)
    
    attempt = 1
    while attempt <= 3 :
        try :
            r = requests.get("https://api.twitter.com/1.1/search/tweets.json?" + query, auth=oauth)
            return json.loads(r.text)
        
        except (ConnectionError, HTTPError) as err :
            sleep_time = 2**(attempt - 1)
            print("Connection attempt " + str(attempt) + " failed. "
                "Sleeping for " + str(sleep_time) + " second(s).")
            time.sleep(sleep_time)
            attempt = attempt + 1
    
    print("***** Error: Unable to query Twitter. Terminating.")

# %% [markdown]
# The function below just ensures that our query begins with "q=" as this is the format twitter requires. All of the jobs in the job table already have a "q=" but this acts as just a fail-safe.

# %%
def getFullQuery(query) :
    if (not query.startswith("q=")) :
        query = "q=" + query
    return query

# %% [markdown]
# And now we structure our data!

# %%
def structureTweetTable(tweet, job):
   
    list_o_dicts = []
    
    for i in tweet['statuses']:
        d = {}
        d['tweet_id_str'] =  i["id_str"] 
        d['job_id'] = job
        d['created_at'] = datetime.strptime(i["created_at"], '%a %b %d %H:%M:%S +0000 %Y').strftime('%Y-%m-%d %H:%M:%S')
        d['text'] = i["text"]
        d['from_user'] = i["user"]["id"]
        d['from_user_id_str'] = i["user"]["id_str"]
        d['from_user_name']  = i["user"]["screen_name"]
        d['from_user_fullname'] = i["user"]["name"]
        d['from_user_created_at'] = datetime.strptime(i["user"]["created_at"], '%a %b %d %H:%M:%S +0000 %Y').strftime('%Y-%m-%d %H:%M:%S')
        d['from_user_followers'] = i["user"]["followers_count"]
        d['from_user_following'] = i["user"]["friends_count"]
        d['from_user_favorites'] = i["user"]["favourites_count"]
        d['from_user_tweets'] = i["user"]["statuses_count"]
        d['from_user_timezone'] = i["user"]["time_zone"]
        d['to_user'] = i["in_reply_to_user_id"]
        d['to_user_id_str'] = i["in_reply_to_user_id_str"]
        d['to_user_name'] = i["in_reply_to_screen_name"]
        d['source'] = i["source"]
        d['iso_language'] = i["metadata"]["iso_language_code"]
        if i['geo'] is not None and i['geo']['type'] == "Point" :
            d['location_geo'] = 'Point({},{})'.format(i['geo']["coordinates"][0],i['geo']["coordinates"][1])
            d['location_geo_0'] = '{}'.format(i['geo']["coordinates"][0])
            d['location_geo_1'] = '{}'.format(i['geo']["coordinates"][1])
        
        list_o_dicts.append(d)

    return list_o_dicts

# %% [markdown]
# And now we put it all together and collect tweets from each job once. Each job run becomes a data frame that will then be appended to the list object `frames`.

# %%
frames = []
for index, row in job.iterrows():
    
    job_id = row['job_id']

    q = getFullQuery(row['query'])
    results = search(q,oauth)
    try:
        f = pd.DataFrame(structureTweetTable(results,job_id))
        frames.append(f)
    except:
        print("   no results returned for '{}'".format(row['query']))
        pass
# Out:
# Query: q=Warren
# Query: q=Fresno
# Query: q=Cincinnati
# Query: q=Oklahoma%20City
# Query: q=Allentown
# Query: q=Columbia
# Query: q=Cleveland
# Query: q=Des%20Moines
# Query: q=Grand%20Rapids
# Query: q=Rochester
# Query: q=Peoria
# Query: q=Springfield
# Query: q=Lafayette
# Query: q=Overland%20Park
# Query: q=Milwaukee
# Query: q=Henderson
# Query: q=Charlotte
# Query: q=Chicago
# Query: q=Brownsville
# Query: q=Boston
# Query: q=Baton%20Rouge
# Query: q=Chandler
# Query: q=Reno
# Query: q=Santa%20Ana
# Query: q=New%20Haven
# Query: q=Broken%20Arrow
# Query: q=Edison
# Query: q=Rockford
# Query: q=Philadelphia
# Query: q=West%20Jordan
# Query: q=Winston%20Salem
# Query: q=Shreveport
# Query: q=El%20Paso
# Query: q=Birmingham
# Query: q=Buffalo
# Query: q=New%20York%20City
# Query: q=Evansville
# Query: q=Charleston
# Query: q=Saint%20Paul
# Query: q=Gresham
# Query: q=Alexandria
# Query: q=Houston
# Query: q=Peoria
# Query: q=North%20Charleston
# Query: q=Provo
# Query: q=Norman
# Query: q=Augusta
# Query: q=Seattle
# Query: q=Durham
# Query: q=Indianapolis
# Query: q=st%20paul
# Query: q=&geocode=42.5144566,-83.01465259999999,40km
# Query: q=&geocode=36.7468422,-119.7725868,40km
# Query: q=&geocode=39.103118200000004,-84.5120196,40km
# Query: q=&geocode=35.4675602,-97.5164276,40km
# Query: q=&geocode=40.6084305,-75.4901833,40km
# Query: q=&geocode=38.95170529999999,-92.33407240000001,40km
# Query: q=&geocode=41.499320000000004,-81.6943605,40km
# Query: q=&geocode=41.600544799999994,-93.6091064,40km
# Query: q=&geocode=42.9633599,-85.6680863,40km
# Query: q=&geocode=44.0121221,-92.4801989,40km
# Query: q=&geocode=33.5805955,-112.23737790000001,40km
# Query: q=&geocode=37.20895720000001,-93.2922989,40km
# Query: q=&geocode=30.2240897,-92.0198427,40km
# Query: q=&geocode=38.9822282,-94.6707917,40km
# Query: q=&geocode=43.0389025,-87.9064736,40km
# Query: q=&geocode=36.0395247,-114.9817213,40km
# Query: q=&geocode=35.2270869,-80.8431267,40km
# Query: q=&geocode=41.8781136,-87.62979820000001,40km
# Query: q=&geocode=25.9017472,-97.4974838,40km
# Query: q=&geocode=42.360082500000004,-71.0588801,40km
# Query: q=&geocode=30.458282899999997,-91.1403196,40km
# Query: q=&geocode=33.3061605,-111.8412502,40km
# Query: q=&geocode=39.529632899999996,-119.8138027,40km
# Query: q=&geocode=33.7455731,-117.8678338,40km
# Query: q=&geocode=41.308274,-72.9278835,40km
# Query: q=&geocode=36.060949,-95.7974526,40km
# Query: q=&geocode=40.5187154,-74.4120953,40km
# Query: q=&geocode=42.2711311,-89.09399520000001,40km
# Query: q=&geocode=39.9525839,-75.1652215,40km
# Query: q=&geocode=40.6096698,-111.9391031,40km
# Query: q=&geocode=36.0998596,-80.24421600000001,40km
# Query: q=&geocode=32.5251516,-93.75017890000001,40km
# Query: q=&geocode=31.7618778,-106.48502169999999,40km
# Query: q=&geocode=33.5206608,-86.80249,40km
# Query: q=&geocode=42.8864468,-78.8783689,40km
# Query: q=&geocode=40.7127837,-74.00594129999999,40km
# Query: q=&geocode=37.9715592,-87.5710898,40km
# Query: q=&geocode=32.776474900000004,-79.9310512,40km
# Query: q=&geocode=44.953702899999996,-93.0899578,40km
# Query: q=&geocode=45.5001357,-122.43020130000001,40km
# Query: q=&geocode=38.804835499999996,-77.0469214,40km
# Query: q=&geocode=29.7604267,-95.36980279999999,40km
# Query: q=&geocode=40.6936488,-89.58898640000001,40km
# Query: q=&geocode=32.8546197,-79.9748103,40km
# Query: q=&geocode=40.233843799999995,-111.6585337,40km
# Query: q=&geocode=35.222566799999996,-97.4394777,40km
# Query: q=&geocode=33.4734978,-82.0105148,40km
# Query: q=&geocode=47.6062095,-122.33207079999998,40km
# Query: q=&geocode=35.99403289999999,-78.898619,40km
# Query: q=&geocode=39.768403,-86.158068,40km

# %%
frame = pd.concat(frames)

# %% [markdown]
# # Your turn...
#
# From the data collected, create the following tables:
# 1. a table of hashtags
#     - collect the hashtagged texts from each of the tweets
# 2. a table of mentions
#     - collect all of the mentions ("@username") from each tweet
# 3. a table of urls
#     - collect all of the urls from each tweet
#
#
# Remember that you are structuring a database, so be sure to carry over the proper attributes in order to construct relations between other tables.

# %%
# Your Code (create as many cells as you need)
# --------------------------------------------
alls = []
for i, row in frame.iterrows():
    stuff = {tag.strip("#") for tag in row['text'].split() if tag.startswith("#")}
    if len(stuff) > 0:
        tweets = [[i] * len(stuff)]
        jobs = [[row['job_id']] * len(stuff)]
        f = pd.DataFrame({'tweet_id' : tweets[0], 'hastag' : list(stuff), 'job_id': jobs[0]})
        alls.append(f)

# %%
pd.concat(alls).reset_index().drop('index', axis = 1)
# Out:
#                  hastag  job_id  tweet_id
# 0              giveaway     204         4
# 1                travel     204         4
# 2                 Trump     204         7
# 3             Democrats     204         7
# 4          Election2020     204         7
# 5       ElizabethWarren     204         7
# 6                evans…     204        12
# 7                 Black     205         0
# 8                  jobs     205         6
# 9                Indeed     205         6
# 10                TODAY     205         9
# 11                TODAY     205        10
# 12           NowPlaying     205        12
# 13             Oakland.     205        14
# 14               career     206         0
# 15               hiring     206         0
# 16          Cincinnati,     206         0
# 17           Cincinnati     206         1
# 18                 Ohio     206         2
# 19                   OH     206         2
# 20                 Ohio     206         3
# 21                   OH     206         3
# 22              Brewers     206         6
# 23               Ticket     206         6
# 24              LouCity     206        10
# 25                  OTT     206        14
# 26          multiscreen     206        14
# 27    contentprotection     206        14
# 28                  nba     207         8
# 29            thunderup     207         8
# ..                  ...     ...       ...
# 757        relationship     299        12
# 758              fetish     299        12
# 759              Pessac     299        12
# 760           skypeshow     299        12
# 761    MacNCheeseMonday     299        14
# 762        godofthegaps     300         7
# 763              Monday     300        11
# 764            UVUALLIN     300        14
# 765        UVUSOFTBALL…     300        14
# 766         SoundBites.     301         7
# 767         rgmtalkback     301         8
# 768                  p…     302         3
# 769                  p…     302         4
# 770                  p…     302         5
# 771         deandacosta     303         6
# 772    mondaymotivation     303         9
# 773       Elections2018     303        13
# 774  nikon_photography_     304         0
# 775             nikonlo     304         0
# 776                 job     304         2
# 777            Raleigh,     304         2
# 778               USMNT     304         4
# 779         NHLPlayoffs     304        11
# 780              Thich…     304        14
# 781     IndianaPotholes     305         5
# 782      100DaysOfShame     305         8
# 783          RESISTANCE     305         8
# 784      BurrMustRecuse     305         8
# 785              myhfa…     305        12
# 786          hpmkt2016,     305        12
#
# [787 rows x 3 columns]

# %%
frame
# Out:
#              created_at           from_user from_user_created_at  \
# 0   2017-04-24 16:42:03           396702061  2011-10-23 17:08:54
# 1   2017-04-24 16:42:01          2715717762  2014-08-08 00:54:17
# 2   2017-04-24 16:41:58            22144947  2009-02-27 14:34:36
# 3   2017-04-24 16:41:47            23019548  2009-03-06 02:49:25
# 4   2017-04-24 16:41:46           151405084  2010-06-03 09:58:30
# 5   2017-04-24 16:41:36          4724224163  2016-01-06 11:34:58
# 6     Philosophical14God  852867577730695169       God14Peace
# 7                  Tyler          2271670922        V_I_uMsic
# 8           Luigi Warren          2577053906     luigi_warren
# 9        abigail grammer          3487132335         abbgramm
# 10                  Ruke          2974049068        LukeTheHo
# 11          Luigi Warren          2577053906     luigi_warren
# 12            jerri wolf           726756098       jerri_wolf
# 13             @THE.GOAT          3168138558          Treentp
# 14                bieber  772550317296803840      Kennyheroin
# 0                     Me            27678383          m00sha7
# 1               angelica          1038861175  grizzlyangelica
# 2      Gibson Elementary          2324589050     RuthGibsonES
# 3                    #11           372113617   Team_Fresno_11
# 4           Chuck Meyers  831295311154921474      cmeyers1610
# 5   American Patriot 2.0            18423683       dadofthree
# 6                  Lyons           390372276      LyonsMagnus
# 7                 Expaña           232818847     quepaisanaje
# 8            Conor Myles           423945466       MylesSheet
# 9             Info 24 US          2690281202         Info24US
# 10       The Truth 24 US          2941365709     TheTruth24US
# 11             Jan Roper           488706702         danojano
# 12                 lucas           344810959  eulucascarvalho
# 13         Carol Peaslee           325880081    Carol_Peaslee
# 14               .......          1639144405    TrueBlue559CA
# ..                   ...                 ...              ...
# 0          Jan Berkowitz          4230529475    jan_berkowitz
# 1                      X           339136008   WentzFutureMvP
# 2   TMJ-RDU Nursing Jobs            22147873  tmj_rdu_nursing
# 3            Emmanuel🇧🇿🌴  697239727582400513      manny_pesos
# 4    Oak City Supporters          3003646781       OCSRaleigh
# 5        Matt_Littlejohn            14863299  Matt_Littlejohn
# 6                 🌬Xina🌀          1598408126  radionradiation
# 7                  Mílan          4239312076     TheRealVic__
# 8                   Greg            76734705  GregMcNamaraRDU
# 9              daraaa ‼️          2950360361     dara_odumosu
# 10        Lindsay Wagner          1195538370  LindsayWagnerNC
# 11      Canes and Coffee          3290598154   CanesandCoffee
# 12       kristen daniels           115763911        ksdincary
# 13               The COO           543553285      TheZompster
# 14         leatham green           254703760   engagethedream
# 0             Matt Tebbe           114873081        matttebbe
# 1            Grandpa Ken           552551826         Kenr3378
# 2             GodComplex  708742264063979520            gbc9f
# 3                 memmy.           109367506       emmyabrams
# 4                  Kampy            33156452          kampydk
# 5      Indiana House GOP           118850657       INHouseGOP
# 6                  Andie           620697301        AndieLeeZ
# 7                 afnunz           181833736          afnunz_
# 8       patricia faiella          1687468122          PBarnat
# 9         Indy Grapevine          2375510874   Indy_Grapevine
# 10                   Zar  713396967695589376      zariajwhite
# 11             YUTA MUTO           164285452        Yuta_Muto
# 12        Felicia Savage           226776986    KittyHasFleaz
# 13               Curdine  790995437629140992        curdine16
# 14                    P👑          3184423832  Imperfprincesss
#
#             from_user_timezone         ...          job_id  \
# 0   Pacific Time (US & Canada)         ...             204
# 1   Eastern Time (US & Canada)         ...             204
# 2   Eastern Time (US & Canada)         ...             204
# 3       Atlantic Time (Canada)         ...             204
# 4                        Tokyo         ...             204
# 5   Pacific Time (US & Canada)         ...             204
# 6                         None         ...             204
# 7   Pacific Time (US & Canada)         ...             204
# 8   Pacific Time (US & Canada)         ...             204
# 9   Pacific Time (US & Canada)         ...             204
# 10                        None         ...             204
# 11  Pacific Time (US & Canada)         ...             204
# 12      Atlantic Time (Canada)         ...             204
# 13                        None         ...             204
# 14                        None         ...             204
# 0                         None         ...             205
# 1   Pacific Time (US & Canada)         ...             205
# 2   Pacific Time (US & Canada)         ...             205
# 3   Pacific Time (US & Canada)         ...             205
# 4                         None         ...             205
# 5   Pacific Time (US & Canada)         ...             205
# 6   Pacific Time (US & Canada)         ...             205
# 7                       Madrid         ...             205
# 8       Atlantic Time (Canada)         ...             205
# 9                      Caracas         ...             205
# 10                     Caracas         ...             205
# 11  Eastern Time (US & Canada)         ...             205
# 12                   Greenland         ...             205
# 13  Central Time (US & Canada)         ...             205
# 14                        None         ...             205
# ..                         ...         ...             ...
# 0   Eastern Time (US & Canada)         ...             304
# 1   Pacific Time (US & Canada)         ...             304
# 2   Eastern Time (US & Canada)         ...             304
# 3                         None         ...             304
# 4   Eastern Time (US & Canada)         ...             304
# 5   Eastern Time (US & Canada)         ...             304
# 6       Atlantic Time (Canada)         ...             304
# 7   Pacific Time (US & Canada)         ...             304
# 8                        Quito         ...             304
# 9                         None         ...             304
# 10  Pacific Time (US & Canada)         ...             304
# 11                        None         ...             304
# 12  Eastern Time (US & Canada)         ...             304
# 13  Eastern Time (US & Canada)         ...             304
# 14                      Hawaii         ...             304
# 0               Indiana (East)         ...             305
# 1                         None         ...             305
# 2                         None         ...             305
# 3   Central Time (US & Canada)         ...             305
# 4   Eastern Time (US & Canada)         ...             305
# 5   Eastern Time (US & Canada)         ...             305
# 6       Atlantic Time (Canada)         ...             305
# 7   Pacific Time (US & Canada)         ...             305
# 8                         None         ...             305
# 9                         None         ...             305
# 10                        None         ...             305
# 11                       Tokyo         ...             305
# 12  Eastern Time (US & Canada)         ...             305
# 13                        None         ...             305
# 14                        None         ...             305
#
#                      location_geo  location_geo_0 location_geo_1  \
# 0                             NaN             NaN            NaN
# 1                             NaN             NaN            NaN
# 2                             NaN             NaN            NaN
# 3                             NaN             NaN            NaN
# 4                             NaN             NaN            NaN
# 5                             NaN             NaN            NaN
# 6                             NaN             NaN            NaN
# 7                             NaN             NaN            NaN
# 8                             NaN             NaN            NaN
# 9                             NaN             NaN            NaN
# 10                            NaN             NaN            NaN
# 11                            NaN             NaN            NaN
# 12                            NaN             NaN            NaN
# 13                            NaN             NaN            NaN
# 14                            NaN             NaN            NaN
# 0                             NaN             NaN            NaN
# 1                             NaN             NaN            NaN
# 2                             NaN             NaN            NaN
# 3                             NaN             NaN            NaN
# 4                             NaN             NaN            NaN
# 5                             NaN             NaN            NaN
# 6                             NaN             NaN            NaN
# 7                             NaN             NaN            NaN
# 8                             NaN             NaN            NaN
# 9                             NaN             NaN            NaN
# 10                            NaN             NaN            NaN
# 11                            NaN             NaN            NaN
# 12                            NaN             NaN            NaN
# 13                            NaN             NaN            NaN
# 14                            NaN             NaN            NaN
# ..                            ...             ...            ...
# 0                             NaN             NaN            NaN
# 1                             NaN             NaN            NaN
# 2   Point(35.7744301,-78.6313624)      35.7744301    -78.6313624
# 3                             NaN             NaN            NaN
# 4                             NaN             NaN            NaN
# 5                             NaN             NaN            NaN
# 6                             NaN             NaN            NaN
# 7                             NaN             NaN            NaN
# 8                             NaN             NaN            NaN
# 9                             NaN             NaN            NaN
# 10                            NaN             NaN            NaN
# 11                            NaN             NaN            NaN
# 12                            NaN             NaN            NaN
# 13                            NaN             NaN            NaN
# 14                            NaN             NaN            NaN
# 0                             NaN             NaN            NaN
# 1                             NaN             NaN            NaN
# 2                             NaN             NaN            NaN
# 3                             NaN             NaN            NaN
# 4                             NaN             NaN            NaN
# 5                             NaN             NaN            NaN
# 6                             NaN             NaN            NaN
# 7                             NaN             NaN            NaN
# 8                             NaN             NaN            NaN
# 9                             NaN             NaN            NaN
# 10                            NaN             NaN            NaN
# 11                            NaN             NaN            NaN
# 12                            NaN             NaN            NaN
# 13                            NaN             NaN            NaN
# 14                            NaN             NaN            NaN
#
#                                                source  \
# 0   <a href="http://www.facebook.com/twitter" rel=...
# 1   <a href="http://twitter.com" rel="nofollow">Tw...
# 2   <a href="http://twitter.com/#!/download/ipad" ...
# 3   <a href="http://twitter.com/download/iphone" r...
# 4   <a href="http://paper.li" rel="nofollow">Paper...
# 5   <a href="http://twitter.com/download/iphone" r...
# 6   <a href="http://twitter.com" rel="nofollow">Tw...
# 7   <a href="http://twitter.com" rel="nofollow">Tw...
# 8   <a href="http://twitter.com" rel="nofollow">Tw...
# 9   <a href="http://twitter.com/download/iphone" r...
# 10  <a href="http://twitter.com/download/iphone" r...
# 11  <a href="http://twitter.com" rel="nofollow">Tw...
# 12  <a href="http://twitter.com" rel="nofollow">Tw...
# 13  <a href="http://twitter.com/download/iphone" r...
# 14  <a href="http://twitter.com/download/android" ...
# 0   <a href="http://twitter.com/download/android" ...
# 1   <a href="http://twitter.com/download/iphone" r...
# 2   <a href="http://twitter.com/download/iphone" r...
# 3   <a href="http://twitter.com/download/android" ...
# 4   <a href="http://twitter.com/download/android" ...
# 5   <a href="http://twitter.com/download/android" ...
# 6   <a href="http://www.indeed.com" rel="nofollow"...
# 7   <a href="http://twitter.com" rel="nofollow">Tw...
# 8   <a href="http://twitter.com/download/iphone" r...
# 9   <a href="http://reporte.us" rel="nofollow">Rep...
# 10  <a href="http://reporte.us" rel="nofollow">Rep...
# 11  <a href="http://twitter.com/download/android" ...
# 12  <a href="http://spotify.com" rel="nofollow">Sp...
# 13  <a href="http://twitter.com" rel="nofollow">Tw...
# 14  <a href="http://www.echofon.com/" rel="nofollo...
# ..                                                ...
# 0   <a href="https://ifttt.com" rel="nofollow">IFT...
# 1   <a href="http://twitter.com/download/iphone" r...
# 2   <a href="http://www.tweetmyjobs.com" rel="nofo...
# 3   <a href="http://twitter.com/download/iphone" r...
# 4   <a href="http://twitter.com/download/iphone" r...
# 5   <a href="http://twitter.com/download/iphone" r...
# 6   <a href="http://twitter.com/download/android" ...
# 7   <a href="http://twitter.com/download/iphone" r...
# 8   <a href="http://twitter.com/download/iphone" r...
# 9   <a href="http://twitter.com/download/iphone" r...
# 10  <a href="http://twitter.com" rel="nofollow">Tw...
# 11  <a href="http://twitter.com" rel="nofollow">Tw...
# 12  <a href="http://twitter.com/download/iphone" r...
# 13  <a href="http://twitter.com/download/iphone" r...
# 14  <a href="http://twitter.com" rel="nofollow">Tw...
# 0   <a href="http://twitter.com" rel="nofollow">Tw...
# 1   <a href="http://twitter.com/download/android" ...
# 2   <a href="http://twitter.com/download/android" ...
# 3   <a href="http://twitter.com/download/iphone" r...
# 4   <a href="http://twitter.com/download/android" ...
# 5   <a href="http://twitter.com" rel="nofollow">Tw...
# 6   <a href="http://twitter.com/download/iphone" r...
# 7   <a href="http://twitter.com/download/iphone" r...
# 8   <a href="http://twitter.com/download/android" ...
# 9   <a href="https://www.socialoomph.com" rel="nof...
# 10  <a href="http://twitter.com/download/iphone" r...
# 11  <a href="http://twitter.com" rel="nofollow">Tw...
# 12  <a href="http://twitter.com" rel="nofollow">Tw...
# 13  <a href="http://twitter.com/download/android" ...
# 14  <a href="http://twitter.com/download/iphone" r...
#
#                                                  